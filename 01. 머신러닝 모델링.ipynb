# %% [markdown]
# # 모델링 개요

# %% [markdown]
# ## 0.환경준비

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ## 1.데이터 로딩

# %%
path = 'https://raw.githubusercontent.com/DA4BAM/dataset/master/advertising.csv'
data = pd.read_csv(path)

data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %% [markdown]
# * TV, Radio, Newspaper 광고비용 지출에 따른 판매액 데이터
# * 광고비용을 어떻게 지출하느냐에 따라 매출액은 어떻게 달라지는지

# %% [markdown]
# ## 2.데이터 전처리

# %%
target = 'Sales'
x = data.drop(target, axis=1)
y = data.loc[:, target]

# %%
x.head()

# %%
y.head()

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %% [markdown]
# ## 3.학습

# %% [markdown]
# * 필요한 함수들 불러오기

# %%
from sklearn.linear_model import LinearRegression

from sklearn.metrics import mean_absolute_error

# %% [markdown]
# * 모델 선언하기

# %%
model = LinearRegression()

# %% [markdown]
# * 학습

# %%
model.fit(x_train, y_train)

# %% [markdown]
# ## 4.예측
# * 학습의 결과 모델이 만들어 집니다.
# * 모델이 얼마나 정확한지 검증해 봅시다.

# %%
pred = model.predict(x_test)

# %%
pred

# %% [markdown]
# ## 5.평가

# %%
mean_absolute_error(y_test, pred)

# %% [markdown]
# # 실습1 : Diamond Price 예측
# * 위 코드를 보면서 그대로 따라해보기

# %% [markdown]
# ## 1.데이터 로딩

# %%
path = 'https://raw.githubusercontent.com/DA4BAM/dataset/master/diamonds.csv'
data = pd.read_csv(path)
data = data.sample(2000, random_state=20)
data.head()
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z
# 20244   1.52     Fair     H     VS2   62.1   66.0   8674  7.33  7.13  4.50
# 45013   0.54  Premium     G     VS2   62.0   58.0   1637  5.21  5.18  3.22
# 53351   0.70  Premium     E     VS2   62.0   60.0   2657  5.70  5.59  3.50
# 47212   0.59    Ideal     E     VS2   62.2   58.0   1838  5.35  5.39  3.34
# 1460    0.86  Premium     F     SI2   61.8   58.0   2980  6.12  6.15  3.79

# %% [markdown]
# ## 2.데이터 전처리

# %% [markdown]
# * 분할1 : x, y

# %% [markdown]
# * 가변수화

# %%
target = 'price'
x = data.drop(target, axis=1)
y = data.loc[:, target]

# %%
x.head()
# Out:
#        carat      cut color clarity  depth  table     x     y     z
# 20244   1.52     Fair     H     VS2   62.1   66.0  7.33  7.13  4.50
# 45013   0.54  Premium     G     VS2   62.0   58.0  5.21  5.18  3.22
# 53351   0.70  Premium     E     VS2   62.0   60.0  5.70  5.59  3.50
# 47212   0.59    Ideal     E     VS2   62.2   58.0  5.35  5.39  3.34
# 1460    0.86  Premium     F     SI2   61.8   58.0  6.12  6.15  3.79

# %%
y.head()
# Out:
# 20244    8674
# 45013    1637
# 53351    2657
# 47212    1838
# 1460     2980
# Name: price, dtype: int64

# %%
col_cat = ['cut','color','clarity']
x = pd.get_dummies(x, columns = col_cat, drop_first = True)

# %%
x.head()
# Out:
#        carat  depth  table     x     y     z  cut_Good  cut_Ideal  \
# 20244   1.52   62.1   66.0  7.33  7.13  4.50     False      False
# 45013   0.54   62.0   58.0  5.21  5.18  3.22     False      False
# 53351   0.70   62.0   60.0  5.70  5.59  3.50     False      False
# 47212   0.59   62.2   58.0  5.35  5.39  3.34     False       True
# 1460    0.86   61.8   58.0  6.12  6.15  3.79     False      False
#
#        cut_Premium  cut_Very Good  ...  color_H  color_I  color_J  clarity_IF  \
# 20244        False          False  ...     True    False    False       False
# 45013         True          False  ...    False    False    False       False
# 53351         True          False  ...    False    False    False       False
# 47212        False          False  ...    False    False    False       False
# 1460          True          False  ...    False    False    False       False
#
#        clarity_SI1  clarity_SI2  clarity_VS1  clarity_VS2  clarity_VVS1  \
# 20244        False        False        False         True         False
# 45013        False        False        False         True         False
# 53351        False        False        False         True         False
# 47212        False        False        False         True         False
# 1460         False         True        False        False         False
#
#        clarity_VVS2
# 20244         False
# 45013         False
# 53351         False
# 47212         False
# 1460          False
#
# [5 rows x 23 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %% [markdown]
# ## 3.학습

# %%
from sklearn.linear_model import LinearRegression

from sklearn.metrics import mean_absolute_error

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## 4.예측

# %%
pred = model.predict(x_test)

# %%
pred
# Out:
# array([ 2.42709832e+02,  1.78737881e+03,  6.09707981e+02,  2.21223117e+02,
#        -6.03327941e+02,  2.76450443e+03,  2.24346756e+03,  9.94323576e+03,
#         5.20350619e+02,  6.23078087e+03,  2.62521647e+03,  5.92636667e+03,
#         1.21462853e+03,  4.92720318e+02,  1.44933026e+03,  5.29426324e+03,
#         1.23199369e+04,  1.25063081e+04,  2.31725065e+03,  2.71741872e+03,
#        -6.39187531e+02,  1.42827571e+04,  1.18000410e+04,  2.09094851e+03,
#        -3.51271335e+01, -5.22135720e+02,  1.75316896e+03, -3.46416166e+01,
#         4.33514997e+03,  1.12372463e+04,  4.37224623e+03,  3.88610462e+03,
#         5.21563185e+02,  4.73623815e+03,  5.84948978e+03,  2.78585917e+03,
#         7.95812594e+03,  2.42043324e+03,  1.13873045e+03,  6.12121082e+03,
#         8.02300816e+03,  1.82953306e+03,  9.23828284e+01,  2.05561009e+03,
#         1.79445111e+03,  4.59011760e+03,  7.58232466e+02,  4.71559149e+03,
#         5.46373502e+03,  1.43158104e+04,  1.77720028e+03,  6.40162002e+03,
#         1.09207304e+03,  6.98962834e+03,  4.91166905e+02,  6.52862203e+02,
#         1.13588468e+03,  1.40108427e+03,  2.01261598e+03,  2.07763527e+03,
#        -4.45685380e+02,  5.12408017e+03,  1.06128859e+03,  1.48700204e+04,
#         3.65426430e+03,  4.99440963e+03,  3.32316640e+03,  7.18832505e+03,
#        -1.78296361e+03,  1.04663777e+04,  1.38338005e+03,  8.75619639e+03,
#         3.87110699e+03,  3.56144596e+03,  1.43955777e+04,  2.48959634e+03,
#        -6.52219457e+02,  2.36847969e+03,  2.40369218e+03,  1.18028525e+03,
#         8.26994436e+03, -2.61281287e+02,  2.22775786e+03,  4.14113380e+03,
#         2.96778716e+02,  4.36195850e+03,  5.72377620e+03,  5.27324532e+02,
#         1.34359045e+03,  1.53615842e+03,  6.82557524e+02,  2.96550478e+03,
#         1.48714189e+03,  1.67256267e+03,  1.79554106e+02,  1.54188111e+03,
#         5.85626077e+03,  4.48811029e+03,  8.65888028e+03,  1.00286687e+03,
#         3.17331683e+03,  1.51062264e+03,  1.84493358e+03,  9.95025738e+03,
#         2.36741664e+03,  9.52318284e+02, -1.44999885e+03,  6.02381071e+03,
#         6.67340299e+03,  4.53932107e+03,  1.38818920e+03,  2.08590852e+02,
#        -4.31710196e+02,  5.99309488e+03,  2.50103421e+03,  1.80743535e+03,
#         1.05070461e+04,  7.16082792e+03,  5.02891413e+02,  7.08799489e+02,
#         8.10394446e+03,  1.41470952e+04,  2.36430245e+02,  9.81132457e+03,
#         1.19103050e+04,  9.82883907e+03,  1.20521572e+04,  2.26524101e+03,
#         6.11366416e+03,  3.01388772e+03,  2.11192331e+03, -4.59675939e+02,
#         3.90566925e+02,  1.28426291e+03,  4.04850119e+03,  3.18620925e+03,
#         6.92536179e+03,  9.83986378e+03,  3.32706376e+03,  1.21606731e+03,
#         7.43143778e+01,  2.22159710e+03,  4.17751941e+03,  1.50971632e+04,
#        -1.12833356e+02,  3.32670486e+03,  8.75704355e+02,  1.67950641e+03,
#         1.47792724e+03,  6.34892992e+03,  5.25740131e+02,  2.48697404e+02,
#         4.27093826e+03,  1.52146711e+03,  1.46970335e+03,  9.72757297e+02,
#         7.65033415e+03,  1.57805946e+03,  7.96505298e+02,  9.93558594e+03,
#         2.51467477e+03,  2.95957897e+03,  1.13595222e+03, -2.25925198e+02])

# %% [markdown]
# ## 5.평가

# %%
mean_absolute_error(y_test, pred)
# Out:
# 745.8526652014851

# %% [markdown]
# # 실습2 : 보스턴시 타운별 집값 예측
# * 위 코드를 보면서 그대로 따라해보기

# %% [markdown]
# ## 1.데이터 로딩

# %%
path = 'https://raw.githubusercontent.com/DA4BAM/dataset/master/boston.csv'
cols = ['crim','indus','chas','nox','rm', 'dis', 'tax','ptratio','lstat','medv']
data = pd.read_csv(path, usecols = cols)
data.head()
# Out:
#       crim  indus  chas    nox     rm     dis  tax  ptratio  lstat  medv
# 0  0.00632   2.31     0  0.538  6.575  4.0900  296     15.3   4.98  24.0
# 1  0.02731   7.07     0  0.469  6.421  4.9671  242     17.8   9.14  21.6
# 2  0.02729   7.07     0  0.469  7.185  4.9671  242     17.8   4.03  34.7
# 3  0.03237   2.18     0  0.458  6.998  6.0622  222     18.7   2.94  33.4
# 4  0.06905   2.18     0  0.458  7.147  6.0622  222     18.7   5.33  36.2

# %% [markdown]
# ## 2.데이터 전처리

# %%
target = 'medv'
x = data.drop(target, axis=1)
y = data.loc[:, target]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %% [markdown]
# ## 3.학습

# %%
from sklearn.linear_model import LinearRegression

from sklearn.metrics import mean_absolute_error

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## 4.예측

# %%
pred = model.predict(x_test)

# %% [markdown]
# ## 5.평가

# %%
mean_absolute_error(y_test, pred)
# Out:
# 3.7513758831716473
